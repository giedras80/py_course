# %%
# L8

# %%
print("a", 'g", c"', 'b', sep="***")
# Out:
# a***g", c"***b

# %%
1000
# Out:
# 1000

# %%
100/12
# Out:
# 8.333333333333334

# %%
1000/6
# Out:
# 166.66666666666666

# %%
1000/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 1000/0
#
# ZeroDivisionError: division by zero

# %%
res = input()
# Out:
#  555

# %%
res - 55
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 res - 55
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
cash = int(input("The amount you want to store up"))
n = int(input("The quantity of months you want to store up:"))
res = cash /n
print(f"You need to put by {res} per month, to save накопить {cash} for {n} months")
# Out:
# The amount you want to store up 100
# The quantity of months you want to store up: 12
# You need to put by 8.333333333333334 per month, to save накопить 100 for 12 months

# %%
try:
    cash = int(input("The amount you want to save"))
    n = int(input("The quantity of months you want to store up: "))
    res = cash /n
    print(f"You need to put by {res} per month, to save {cash} for {n} months")
except:
    print("Error, try again")
# Out:
# The amount you want to save 0
# The quantity of months you want to store up:  0
# Error, try again

# %%
for i in range(5):
    try:
        # ZeroDivisionError ValueError
        cash = int(input("The amount you want to save"))
        n = int(input("The quantity of months you want to store up: "))
        res = cash /n
        print(f"You need to put by {res} per month, to save {cash} for {n} months")
    except:
        print("Error, try again")
# Out:
# The amount you want to save
# Error, try again
# The amount you want to save 0
# The quantity of months you want to store up:  0
# Error, try again
# The amount you want to save 100
# The quantity of months you want to store up:  0
# Error, try again

# %%
try:
    int("trrgug")
except ZeroDivisionError:
    print("Can't divide by zero")
except ValueError:
    print("Don't try to convert a str into int")
except:
    print("Boo!")
# Out:
# Don't try to convert a str into int

# %%
for i in range(5):
    try:

        gdgft
        cash = int(input("The amount you want to save"))
        n = int(input("The quantity of months you want to store up: "))
        res = cash /n
        print(f"You need to put by {res} per month, to save {cash} for {n} months")
    except ZeroDivisionError:
        print("Can't divide by zero")
    except ValueError:
        print("Don't try to convert a str into int")
    except:
        print("Error, try again")
# Out:
# Error, try again
# Error, try again
# Error, try again
# Error, try again
# Error, try again

# %%
for i in range(5):
    try:
        # ZeroDivisionError ValueError
        cash = int(input("The amount you want to save"))
        n = int(input("The quantity of months you want to store up: "))
        res = cash /n
        print(f"You need to put by {res} per month, to save {cash} for {n} months")
    except ZeroDivisionError as e:
        print("Can't divide by zero")
        print(e)
        print(e.args)
        print(e.with_traceback)
    except ValueError as e:
        print("Don't try to convert a str into int")
        print(e)
        print(e.args)
        print(e.with_traceback)
    except:
        print("Error, try again")
# Out:
# The amount you want to save 1000
# The quantity of months you want to store up:  10
# You need to put by 100.0 per month, to save накопить 1000 for 10 months

# %%
try:
    # ZeroDivisionError ValueError
    cash = int(input("The amount you want to save"))
    n = int(input("The quantity of months you want to store up: "))
    res = cash /n
    print(f"You need to put by {res} per month, to save {cash} for {n} months")
except ZeroDivisionError as e:
    print("Can't divide by zero")
    print(e)
    print(e.args)
    print(e.with_traceback)
except ValueError as e:
    print("Don't try to convert a str into int")
    print(e)
    print(e.args)
    print(e.with_traceback)
except:
    print("Error, try again")
# Out:
# The amount you want to save 500
# The quantity of months you want to store up:  5
# You need to put by 100.0 per month, to save 500 for 5 months

# %%
assert 1

# %%
assert 999

# %%
assert "hello"

# %%
assert [1,2,3]

# %%
assert True

# %%
assert 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 assert 0
#
# AssertionError:

# %%
assert ""
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 assert ""
#
# AssertionError:

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
tp = (1,2,3,4)

# %%
tp.append(312)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tp.append(312)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
raise ZeroDivisionError("1/0 нельзя")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 raise ZeroDivisionError("1/0 нельзя")
#
# ZeroDivisionError: 1/0 нельзя

# %%
try:
    # ZeroDivisionError ValueError.
    # raise ZeroDivisionError.
    # raise ValueError.
    # raise AttributeError.
    cash = int(input("The amount you want to save"))
    n = int(input("The quantity of months you want to store up: "))
    res = cash /n
    print(f"You need to put by {res} per month, to save {cash} for {n} months")
except ZeroDivisionError as e:
    print("Can't divide by zero")
    print(e)
    print(e.args)
    print(e.with_traceback)
except ValueError as e:
    print("Don't try to convert a str into int")
    print(e)
    print(e.args)
    print(e.with_traceback)
except:
    print("Error, try again")
# Out:
# The amount you want to save 200
# The quantity of months you want to store up:  0
# Can't divide by zero
# division by zero
# ('division by zero',)
# <built-in method with_traceback of ZeroDivisionError object at 0x000001AA189626E0>
