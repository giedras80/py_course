# %%
L5 # Git & GitHub

# %%
Home work 4.1

# %%
# Download & install Git - Done

# %%
Home work 4.2

# %%
# Create a Github account - Done

# %%
Home work 4.3

# %%
# gitDemo - Done

# %%
Home work 4.4

# %%
# Tasks: Upload all the course folders to your Git repository “py_course” - Done
