# %%
# L5

# %%
message = ""
key = 2006
secured_message = """"""

for i in message:
    secured_message += chr(ord(i) + key)
    
print(secured_message)

print("Deciphering...")
for i in secured_message:
    print(chr(ord(i)-key), end = "")
# Out:
# Deciphering...

# %%
# encode, decode, askForAMessage, printTheMessage <--- It's difficult to develop by a big team. 
# The large task can be decomposed for these four separate sub-taska (functions?)

# %%
# encode (it will receive a message and a key) ---> (it will return) encoded line
# decode (it will also receive a message and a key) ---> decoded line
# askForAMessage (it will ask to input a message, but it will return the message by a line) ---> message by line
# printTheMessage ---> regular output

# Runner (runApp) (it will start the program, offer a menu, etc)

# %%
# let's try to implement this part:
# askForAMessage (it will ask to input a message, but it will return the message by a line) ---> message by line

# %%
message = input("Give me a message to encode it!")
# Out:
# Give me a message to encode it! aaaaaaaaaaaa

# %%
# if I need to ask this message many times, I should do this:

# %%
message = input("Give me a message to encode it!")
message = input("Give me a message to encode it!")
message = input("Give me a message to encode it!")
message = input("Give me a message to encode it!")
message = input("Give me a message to encode it!")
# Out:
# Give me a message to encode it! aaaaaaa
# Give me a message to encode it! aaaaaaaaaaa
# Give me a message to encode it! aaaaaaaaaaaa
# Give me a message to encode it! aaaaaaaaaaaaaaaaaaaaaa
# Give me a message to encode it! aaaaaaaaaaaaaaaaaaaaaaaaaa

# %%
# it's not convenient!!!!!!!!!!!

# %%
# Imagine I need to change the phrase: I will have to do it many times!!!
# it's NO GOOD!!! it's not the way it should be

# %%
def GiveMeTheMessage():
    message = input("Give me a message to encode it!")

# %%
GiveMeTheMessage()
# Out:
# Give me a message to encode it! aaaaaaaaaaaaaa

# %%
GiveMeTheMessage()
# Out:
# Give me a message to encode it! aaaaaaaaaaaaaaaaaa

# %%
# x 50

# %%
# I input the message and it's taken inside "message"

# %%
# but if I want to see what's inside

# %%
message
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
# OK. And what's inside the function?

# %%
GiveMeTheMessage()
# Out:
# Give me a message to encode it! aaaaaaaaaaaa

# %%
result = GiveMeTheMessage()
# Out:
# Give me a message to encode it! aaaaaaaaaaaaaaaa

# %%
result

# %%
print(result)
# Out:
# None

# %%
def GiveMeTheMessage():
    message = input("Give me a message to encode it!")

    return message

# %%
result = GiveMeTheMessage()
# Out:
# Give me a message to encode it! aaaaaaaaaaa

# %%
result
# Out:
# 'aaaaaaaaaaa'

# %%
# I tought the function to return the value I neeed

# %%
# what if I want the message to be differnt evry time?

# %%
def GiveMeTheMessage(text):
    message = input(text)

    return message

# %%
GiveMeTheMessage()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 GiveMeTheMessage()
#
# TypeError: GiveMeTheMessage() missing 1 required positional argument: 'text'

# %%
GiveMeTheMessage("Give me a message to encode it!")
# Out:
# Give me a message to encode it! aaaaaaaaaaaaaa
# 'aaaaaaaaaaaaaa'

# %%
result
# Out:
# 'aaaaaaaaaaa'

# %%
def summa(a, b):
    return a+b

# %%
summa
# Out:
# <function __main__.summa(a, b)>

# %%
summa()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 summa()
#
# TypeError: summa() missing 2 required positional arguments: 'a' and 'b'

# %%
summa(1,66)
# Out:
# 67

# %%
def raznost (a, b):
    return a-b

# %%
raznost(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 raznost(3)
#
# Cell In[41], line 2, in raznost(amb)
#       1 def raznost (amb):
# ----> 2     return a-b
#
# NameError: name 'a' is not defined

# %%
# a single variable isn't enough

# %%
raznost(3, 4)
# Out:
# -1

# %%
raznost(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 raznost(3,4,5)
#
# TypeError: raznost() takes 2 positional arguments but 3 were given

# %%
message = "Привет!"
key = 2006
secured_message = """"""

for i in message:
    secured_message += chr(ord(i) + key)
    
print(secured_message)

print("Deciphering...")
for i in secured_message:
    print(chr(ord(i)-key), end = "")
# Out:
# ௵ఖఎఈఋఘ߷
# Deciphering...
# Привет!

# %%
# encode, decode, askForAMessage, printTheMessage <--- It's difficult to develop by a big team. 
# The large task can be decomposed for these four separate sub-taska (functions?)

# %%
# encode (it will receive a message and a key) ---> (it will return) encoded line
# decode (it will also receive a message and a key) ---> decoded line
# askForAMessage (it will ask to input a message, but it will return the message by a line) ---> message by line
# printTheMessage ---> regular output

# Runner (runApp) (it will start the program, offer a menu, etc)

# %%
def GiveMeTheMessage(text):
    message = input(text)

    return message

# %%
key = 8

# %%
# print

# %%
def encode(message, k):
    secured_message = """"""

    for i in secured_message:
        secured_message += chr(ord(i) + k)
    return secured_message

# %%
msg = GiveMeTheMessage("Input the message! ")
# Out:
# Input the message!  aaaaaaaaaaaaaaaaaaaa

# %%
print(msg)
# Out:
# aaaaaaaaaaaaaaaaaaaa

# %%
res_msg = encode(msg, key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 res_msg = encode(msg, ky)
#
# NameError: name 'ky' is not defined

# %%
def decode(secured_message, k):
    print("Deciphering...")
    for i in secured_message:
        print(chr(ord(i)-k), end = "")

# %%
de_res_msg = decode(res_msg, key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 de_res_msg = decode(res_msg, key)
#
# NameError: name 'res_msg' is not defined

# %%
def runApp():
    userInput = int(input("1. encode, 2. decode, 0. exit"))
    while userInput != 0:
        key = int(input("Enter the key for the cipher! "))
        msg = GiveMeTheMessage("Input the message! ")
        if userInput == 1:
            res_msg = encode(msg, key)
            print(res_msg)
        elif userInput == 2:
            de_res_msg = decode(res_msg, key)
            prnt(de_res_msg)
        else:
            print("I didn't understand you! Enter again.")
        userInput = int(input("1. encode, 2. decode, 0. exit"))

# %%
runApp()
# Out:
# 1. encode, 2. decode, 0. exit 1
# Enter the key for the cipher!  6
# Input the message!  whassssup
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 runApp()
#
# Cell In[77], line 7, in runApp()
#       3     while userInput != 0:
#       4         key = int(input("Enter the key for the cipher! "))
#       5         msg = GiveMeTheMessage("Input the message! ")
#       6         if userInput == 1:
# ----> 7             res_msg = encode(msg, key)
#       8             print(res_msg)
#       9         elif userInput == 2:
#      10             de_res_msg = decode(res_msg, key)
#
# TypeError: encode() takes 1 positional argument but 2 were given

# %%
runApp()
# Out:
# 1. encode, 2. decode, 0. exit 2
# Enter the key for the cipher!  6
# Input the message!  dtdyfyu
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 runApp()
#
# Cell In[77], line 10, in runApp()
#       6         if userInput == 1:
#       7             res_msg = encode(msg, key)
#       8             print(res_msg)
#       9         elif userInput == 2:
# ---> 10             de_res_msg = decode(res_msg, key)
#      11             prnt(de_res_msg)
#      12         else:
#      13             print("I didn't understand you! Enter again.")
#
# UnboundLocalError: cannot access local variable 'res_msg' where it is not associated with a value

# %%
...

# %%
def registration(name, surname, phone, email):
    print("hello,", name, surname, phone, email)

# %%
registration("iv", "76656954634567ui")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 registration("iv", "76656954634567ui")
#
# TypeError: registration() missing 2 required positional arguments: 'phone' and 'email'

# %%
def registration(name, surname, phone="", email="-"):
    print("hello,", name, surname, phone, email)

# %%
registration("iv", "76656954634567ui")
# Out:
# hello, iv 76656954634567ui  -

# %%
registration("iv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 registration("iv")
#
# TypeError: registration() missing 1 required positional argument: 'surname'

# %%
registration("iv", "76656954634567ui", "bobson")
# Out:
# hello, iv 76656954634567ui bobson -

# %%
def sum(a=10, b=20):
    print(a+b)

# %%
sum()
# Out:
# 30

# %%
sum(44)
# Out:
# 64

# %%
sum(a=44)
# Out:
# 64

# %%
sum(b=35)
# Out:
# 45
