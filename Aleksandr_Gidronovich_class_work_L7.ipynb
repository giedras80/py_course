# %%
#L7

# %%
li = [1, 2, 3, 4, 5]

# %%
se = (1,2,3,4,1,2,3,4)

# %%
tp = (1,2,3,4,5)

# %%
print(type(li))
# Out:
# <class 'list'>

# %%
print(type(se))
# Out:
# <class 'tuple'>

# %%
print(type(tp))
# Out:
# <class 'tuple'>

# %%
a = 1

# %%
aa = 1.

# %%
tp1 = 1,

# %%
tp = 1,2,3,4,5

# %%
print(tp)
# Out:
# (1, 2, 3, 4, 5)

# %%
tp = .0, 1., 4, 5., .9

# %%
print(tp)
# Out:
# (0.0, 1.0, 4, 5.0, 0.9)

# %%
print(tp[-1])
# Out:
# 0.9

# %%
for val in tp :
    print(val)
# Out:
# 0.0
# 1.0
# 4
# 5.0
# 0.9

# %%
for index in range(len(tp)) :
    print(tp[index])
# Out:
# 0.0
# 1.0
# 4
# 5.0
# 0.9

# %%
tp = (777,) + tp[1:]
print(tp)
# Out:
# (777, 1.0, 4, 5.0, 0.9)

# %%
tp = list(tp)
print(tp)
# Out:
# [777, 1.0, 4, 5.0, 0.9]

# %%
tp[1] = 88888
print(tp)
# Out:
# [777, 88888, 4, 5.0, 0.9]

# %%
tp = tuple(tp)
print(tp)
# Out:
# (777, 88888, 4, 5.0, 0.9)

# %%
tp = 1,1,1,1,1
print(tp)
# Out:
# (1, 1, 1, 1, 1)

# %%
def useful(n) :
    tt = ()

# %%
for i in range(n) :
    #Error tt = tt + i
    tt = tt + (i, )
    return tt
# Out:
#   Cell In[35], line 4
#     return tt
#     ^
# SyntaxError: 'return' outside function

# %%
result = useful(4)

# %%
a, b, c, d = useful(4)
print(a, b, c, d)

# %%
a, b, *c = useful(4)
print(a, b, c)

# %%
 _, b, c, _ = useful(4)

# %%
operation = int(input("Choose the action --> "))
    print()

    while operation != 6:
        
        if operation == 1:
            if len(todos) == 0:
                todos.update(u.create_task(0))    
            else:
                todos.update(u.create_task(max(todos.keys())))
            print()
            print("The task was added")

        elif operation == 2:
            if len(todos) == 0:
                print("The task list is empty") 

            else:
                u.view_all_task(todos)

        elif operation == 3:
            print()
            
            try:
                task = todos[int(input("Enter the task's ID --> "))]
                u.paste_separator()
                print(u.view_task(task))
                u.paste_separator()
            except:
                u.print_except()

                elif operation == 4:
            try:
                todos[int(input("Enter the task's ID --> "))]["completed"] = "Completed" if int(input("Enter the installation status (0 - False, 1 - True) --> ")) == 1 else "Not fulfilled"
                print()
                print("The status was changed")
            except:
                u.print_except()

        elif operation == 5:
            print()
            try:
                del todos[int(input("Enter the task's ID --> "))]
                print()
                print("The task was deleted")
            except:
                u.print_except()

        print()
        operation = int(input("Choose the action --> "))


start_app()
