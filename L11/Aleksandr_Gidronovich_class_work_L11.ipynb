# %%
class User:
    counter = 0
    def __init__(self, name):
        self.user_name = name
        User.counter +=1
        
    def get_name(self):
        return f"{self.user_name}"
    def __str__(self):
        return f"User: name: {self.user_name}"
    def __repr__ (self):
        return f"repr User: name: {self.user_name}"

# %%
User.counter
# Out:
# 0

# %%
dina = User("Dina")

# %%
dina
# Out:
# repr User: name: Dina

# %%
dina.get_name()
# Out:
# 'Dina'

# %%
User.counter
# Out:
# 1

# %%
class User:
    counter = 0
    
    def __init__(self, name):
        self.user_name = name
        User.counter +=1
        
    def get_name(self):
        return f"{self.user_name}"
        
    def __str__(self):
        return f"User: name: {self.user_name}"
        
    def __repr__ (self):
        return f"repr User: name: {self.user_name}"
        
    @staticmethod
    def pow_two(n):
        return n**2

# %%
dina = User("Dina")

# %%
dina.pow_two(444)
# Out:
# 197136

# %%
class User:
    counter = 0
    def __init__(self, name):
        self.user_name = name
        User.counter +=1
        
    def get_name(self):
        return f"{self.user_name}"
        
    def __str__(self):
        return f"User: name: {self.user_name}"
        
    def __repr__ (self):
        return f"repr User: name: {self.user_name}"
        

def pow_two(n):
    return n**2

# %%
class User:
    counter = 0
    
    def __init__(self, name):
        self.user_name = name
        User.counter +=1
        
    def get_name(self):
        return f"{self.user_name}"
        
    def __str__(self):
        return f"User: name: {self.user_name}"
        
    def __repr__ (self):
        return f"repr User: name: {self.user_name}"

    @classmethod
    def double_counter(cls):
        cls.counter *= 2

    @classmethod
    def get_counter(cls):
        return cls.counter
        
    @classmethod
    def set_counter(cls, n):
        cls.__counter += n
        
    @staticmethod
    def pow_two(n):
        return n**2

# %%
dina = User("Dina")

# %%
User.counter
# Out:
# 1

# %%
User.counter = User.pow_two(2)

# %%
User.counter
# Out:
# 4

# %%
User.double_counter()

# %%
User.counter
# Out:
# 8

# %%
User.get_counter()
# Out:
# 8

# %%
# User.set_counter(User.pow_two(2)) ?

# %%
User.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'counter': 8,
#               '__init__': <function __main__.User.__init__(self, name)>,
#               'get_name': <function __main__.User.get_name(self)>,
#               '__str__': <function __main__.User.__str__(self)>,
#               '__repr__': <function __main__.User.__repr__(self)>,
#               'double_counter': <classmethod(<function User.double_counter at 0x000001B37A693740>)>,
#               'get_counter': <classmethod(<function User.get_counter at 0x000001B37A693D80>)>,
#               'set_counter': <classmethod(<function User.set_counter at 0x000001B37A693F60>)>,
#               'pow_two': <staticmethod(<function User.pow_two at 0x000001B37A691120>)>,
#               '__static_attributes__': ('user_name',),
#               '__dict__': <attribute '__dict__' of 'User' objects>,
#               '__weakref__': <attribute '__weakref__' of 'User' objects>,
#               '__doc__': None})

# %%
class User:
    counter = 0
    
    def __init__(self, name):
        self.user_name = name
        User.counter +=1


    # альтернативный конструктор
    @classmethod
    def init_incoding_email_age(cls, name, email, age):
        _user = cls(name)
        _user.user_email = email
        _user.user_age = age
        return _user
        
    def get_name(self):
        return f"{self.user_name}"
        
    def __str__(self):
        return f"User: name: {self.user_name}"
        
    def __repr__ (self):
        return f"repr User: name: {self.user_name}"

    @classmethod
    def double_counter(cls):
        cls.counter *= 2

    @classmethod
    def get_counter(cls):
        return cls.counter
        
    @classmethod
    def set_counter(cls, n):
        cls.__counter += n
        
    @staticmethod
    def pow_two(n):
        return n**2

# %%
dina = User("Dina")

# %%
dina.__dict__
# Out:
# {'user_name': 'Dina'}

# %%
extended_dina = User.init_incoding_email_age("extd dina", "emailfjkds@hfhdf", 44)

# %%
extended_dina.__dict__
# Out:
# {'user_name': 'extd dina', 'user_email': 'emailfjkds@hfhdf', 'user_age': 44}

# %%
# Задача

# %%
# Делать экспорт из сервиса в форматы
хранилка - данные

экспорт в:
csv
pdf
json

все эти операции включают:
    что-то проверить 
    подготовить данные
    экспорт

list заказов - [ данные1 --> pdf
                 данные2 --> csv
                 данные3 --> pdf
                 данные4 --> json
               ] 

for заказ in list заказов
    заказ.подготовить 
    заказ.проверить 
    заказ.экспорт

абстрактный класс - 
- класс в котором нет реализации
но есть методы (их сигнатуры без реализации)
------------------------------------------

унаследовать все эти пустые методы 
    и переопределить в конкретных классах

экспорт в:
csv
pdf
json

все эти операции включают:
    что-то проверить 
    подготовить данные
    экспорт

# %%
for ABC import
# Out:
#   Cell In[101], line 1
#     for ABC import
#             ^
# SyntaxError: invalid syntax

# %%
class Task_Export_Data(ABC):
    @abstractmethod
    def prepare(self):
        pass
        
    @abstractmethod
    def export(self):
        pass
        
    @abstractmethod
    def check(self):
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 class Task_Export_Data(ABC):
#       2     @abstractmethod
#       3     def prepare(self):
#       4         pass
#
# NameError: name 'ABC' is not defined

# %%
# csv pdf json

# %%
class json_data(Task_Export_Data):
    
    def __init__(self, data):
        self.__data = data
        
    def check(self):
        print("чтото проверяю json")
        
    def prepare(self):
        print("чтото подготавливаю json")
        
    def export(self):
        print("чтото экспортирую json")
        print(self.__data)


class pdf_data(Task_Export_Data):
    
    def __init__(self, data):
        self.__data = data
        
    def check(self):
        print("чтото проверяю pdf")
        
    def prepare(self):
        print("чтото подготавливаю pdf ")
        
    def export(self):
        print("чтото экспортирую pdf")
        print(self.__data)


class csv_data(Task_Export_Data):
    
    def __init__(self, data):
        self.__data = data
        
    def check(self):
        print("чтото проверяю csv")
        
    def prepare(self):
        print("чтото подготавливаю csv")
        
    def export(self):
        print("чтото экспортирую csv")
        print(self.__data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 class json_data(Task_Export_Data):
#       3     def __init__(self, data):
#       4         self.__data = data
#
# NameError: name 'Task_Export_Data' is not defined

# %%
li = [csv_data("a,b,c,d,e"), pdf_data("sdfsdf sdfsdfsd sdfsdfs s dfsdfs"), json_data('{name:"stas", age: 44}')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 li = [csv_data("a,b,c,d,e"), pdf_data("sdfsdf sdfsdfsd sdfsdfs s dfsdfs"), json_data('{name:"stas", age: 44}')]
#
# NameError: name 'csv_data' is not defined

# %%
for inst in li:
    inst.prepare()
    inst.check()
    inst.export()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 for inst in li:
#       2     inst.prepare()
#       3     inst.check()
#
# NameError: name 'li' is not defined

# %%
# MRO - method resolution order (иерархия наследования)

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

def __repr__(self):
    return f"repr: name:{self.name} |age:{self.age}"

def speak(self, sound):
    return f"{self.name} says {sound}"

# %%
Dog.mro()
# Out:
# [__main__.Dog, object]

# %%
class Bulldog(Dog):
    def walk(self, steps):
        return f"{self.name} ходит {steps} шагов"

    def speak(self, sound):
        par_speak = super().speak(sound)
        par_speak = par_speak.upper()
        return "Bulldog speak\n" + par_speak

        # return "Bulldog speak\n" + super().speak(sound)

# %%
Bulldog.mro()
# Out:
# [__main__.Bulldog, __main__.Dog, object]

# %%
class user 

static - Проверяет имя на len()>0 isalpha()

return False

attributError
usernameError("")

# %%
# custom exceptions кастомные исключения

# %%
try
except .... as e:
except:

# %%
else - еслине было ошибок
finally - отработает всегда

# %%
try:
    1/0
except:
    print(1)
else:
    print("ошибок не было")
finally:
    print("всегда")
# Out:
# 1
# всегда

# %%
def n():
    return 1

# %%
n()
# Out:
# 1

# %%
def n():
    try:
        1+1
    except:
        return 2
    else:
        return 3
    finally:   #в это ветру return лучше не писать, перетрет предыдущие
        return 10000

# %%
n()
# Out:
# 10000

# %%
def n():
    try:
        1+1
    except:
        return True
    else:
        return False
    finally:   #в это ветру return лучше не писать, перетрет предыдущие
        print("close.. coonnn")

# %%
n()
# Out:
# close.. coonnn
# False

# %%
if 1 ==1:
    result = 1000

# %%
result
# Out:
# 1000

# %%
for i in range(2):
    pass

# %%
i
# Out:
# 1

# %%
try:
    1/0
except ZeroDivisionError as e:
    print(id(e))
    print(e)
# Out:
# 1870374821056
# division by zero

# %%
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 e
#
# NameError: name 'e' is not defined

# %%
# Очередь
# Кладем в конец
# Достаем с начала

class storage:
    def __init__(self):
        self.__items = []
    def priemka(self, value):
        self.__items.append(value)
        print("Приемка товара на склад:", value)
    def otgruzka(self):
        try:
            res = self.__items.pop()
            print("Отгрузка товара со склада:", res)
        except IndexError:
            print("Твой склад пуст")
        except:
            print("Какая-то ошибка отгрузки на складе.")
    def get_items(self):
        return self.__items

# %%
s = storage()

# %%
s.get_items()
# Out:
# []

# %%
s.priemka("Товар 1")
# Out:
# Приемка товара на склад: Товар 1

# %%
s.priemka("Товар 2")
# Out:
# Приемка товара на склад: Товар 2

# %%
s.priemka("Товар 3")
# Out:
# Приемка товара на склад: Товар 3

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 3

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 2

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 1

# %%
s.otgruzka()
# Out:
# Твой склад пуст

# %%
class EmptyStorageError(Exception):
    pass

# %%
EmptyStorageError
# Out:
# __main__.EmptyStorageError

# %%
raise EmptyStorageError("На складе закончился товар!")
# Out:
# ---------------------------------------------------------------------------
# EmptyStorageError                         Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 raise EmptyStorageError("На складе закончился товар!")
#
# EmptyStorageError: На складе закончился товар!

# %%
class EmptyStorageError(Exception):
    pass


# Очередь
# Кладем в конец
# Достаем с начала

class storage:
    def __init__(self):
        self.__items = []
        
    def priemka(self, value):
        self.__items.append(value)
        print("Приемка товара на склад:", value)
        
    def otgruzka(self):
        if len(self.__items) == 0:
            raise EmptyStorageError("На складе закончился товар!") 
            
        res = self.__items.pop()
        print("Отгрузка товара со склада:", res)
            
    def get_items(self):
        return self.__items

# %%
s = storage()

# %%
s.get_items()
# Out:
# []

# %%
s.priemka("Товар 1")
# Out:
# Приемка товара на склад: Товар 1

# %%
s.priemka("Товар 1")
# Out:
# Приемка товара на склад: Товар 1

# %%
s.priemka("Товар 2")
# Out:
# Приемка товара на склад: Товар 2

# %%
s.priemka("Товар 3")
# Out:
# Приемка товара на склад: Товар 3

# %%
s.priemka("Товар 4")
# Out:
# Приемка товара на склад: Товар 4

# %%
s.get_items()
# Out:
# ['Товар 1', 'Товар 1', 'Товар 2', 'Товар 3', 'Товар 4']

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 4

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 3

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 2

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 1

# %%
s.otgruzka()
# Out:
# Отгрузка товара со склада: Товар 1

# %%
s.otgruzka()
# Out:
# ---------------------------------------------------------------------------
# EmptyStorageError                         Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 s.otgruzka()
#
# Cell In[187], line 19, in storage.otgruzka(self)
#      17 def otgruzka(self):
#      18     if len(self.__items) == 0:
# ---> 19         raise EmptyStorageError("На складе закончился товар!")
#      21     res = self.__items.pop()
#      22     print("Отгрузка товара со склада:", res)
#
# EmptyStorageError: На складе закончился товар!

# %%
# Lab queue.py


class EmptyStorageError(Exception):
    pass


# Очередь
# Кладем в конец
# Достаем с начала
# фикстуры

class storage:
    def __init__(self):
        self.__items = []
        
    def priemka(self, value):
        self.__items.append(value)
        print("Приемка товара на склад:", value)
        
    def otgruzka(self):
        if len(self.__items) == 0:
            raise EmptyStorageError("На складе закончился товар!") 
            
        res = self.__items.pop()
        print("Отгрузка товара со склада:", res)
            
    def get_items(self):
        return self.__items


class App:
    def __init__(self, storage):
        self.__storage = storage
        
    def run(self):
        oper = input("1 - Приемка, 2 - отгрузка, 3 - вывод всех товаров на складе, 4 - exit")
        while oper != "exit":
            if oper == "1":
                self.__storage.priemka(input("введи товар"))
            elif oper == "2":
                try:
                    self.__storage.otgruzka()
                except EmptyStorageError as e:
                    print("Склад пуст!")
                else:
                    print("Отгрузка прошла успешно.")
            elif oper == "3":
                self.__storage.get_items()
            elif oper == "exit":
                break
            else:
                print("не понимаю")
            oper = input("1 - Приемка, 2 - отгрузка, 3 - вывод всех товаров на складе, 4 - exit") 
        print("Пока")


app = App(storage())

# %%
app.run()
# Out:
# 1 - Приемка, 2 - отгрузка, 3 - вывод всех товаров на складе, 4 - exit 1dfgh
# не понимаю
# 1 - Приемка, 2 - отгрузка, 3 - вывод всех товаров на складе, 4 - exit 1
# введи товар sdfgh
# Приемка товара на склад: sdfgh
# 1 - Приемка, 2 - отгрузка, 3 - вывод всех товаров на складе, 4 - exit 1
# введи товар sdfgfhgj
# Приемка товара на склад: sdfgfhgj
# 1 - Приемка, 2 - отгрузка, 3 - вывод всех товаров на складе, 4 - exit 3
# 1 - Приемка, 2 - отгрузка, 3 - вывод всех товаров на складе, 4 - exit exit
# Пока
