# %%
# L6

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
x = y = z = 8

# %%
x
# Out:
# 8

# %%
y
# Out:
# 8

# %%
z
# Out:
# 8

# %%
print(x, y, z)
# Out:
# 8 8 8

# %%
a, b, c = 7, 8, 9

# %%
print(a, b, c)
# Out:
# 7 8 9

# %%
type(a)
# Out:
# int

# %%
# Dictionary L6

# %%
# di = {
#     "name":"Alex",
#     "age": "99",
#     "phone": "46566344575895"
# }
# print(di.get('name'))

# %%
print(di.get('khkg', -1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(di.get('khkg', -1))
#
# NameError: name 'di' is not defined

# %%
di = dict(name='Alex', age=777)

# %%
print(di.values())
# Out:
# dict_values(['Alex', 777])

# %%
for val in di.values():
    print(val)
# Out:
# Alex
# 777

# %%
di.keys()
for key in di.keys():
    print(key, di.get(key))
# Out:
# name Alex
# age 777

# %%
di.items()
for x,y in di.items():
     print(x,y)
# Out:
# name Alex
# age 777

# %%
for tp in di.items():
    print(tp)
# Out:
# ('name', 'Alex')
# ('age', 777)

# %%
di.update({"age":29})
# print(di)

# %%
 di.pop('age')

del di['name']
'4' in di # True or False

li = [i**2 for i in range(5)]
di = {str(i):i**2 for i in range(5)}
# Out:
#   Cell In[23], line 1
#     di.pop('age')
#     ^
# IndentationError: unexpected indent

# %%
# # Time
import time
print(time.strftime("%a, %d %b %Y %H:%M:%S +0000", time.gmtime()))
# Out:
# Mon, 20 Apr 2026 12:11:47 +0000

# %%
# import calendar
# print(calendar.isleap(2016))
